# %%
import sys
sys.path.append("../scripts")
from news_data_analysis import NewsDataAnalysis
from yfinance_data_analysis import FinanceAnalysis
import warnings
warnings.filterwarnings("ignore")
# Out:
# ...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# NLTK resources downloaded successfully.

# %%
newsDataAnalysis  = NewsDataAnalysis('../src/data/raw/raw_analyst_ratings.csv')
financeAnalysis = FinanceAnalysis('../src/data/raw/NVDA_historical_data.csv')

# %%
newsDataAnalysis.filter_by_stock('NVDA')
newsDataAnalysis.sentiment_analysis()
newsDataAnalysis.topic_analysis()
newsDataAnalysis.publication_timeseries_analysis()
newsDataAnalysis.publisher_analysis()
newsDataAnalysis.organizations_publication()
newsDataAnalysis.save_data('news_analysis_results')
# Out:
# Publication timeseries analysis
# Publisher statistics:
# count           3146
# unique           152
# top       Lisa Levin
# freq             357
# Name: publisher, dtype: object
# Organizations publication analysis:

# %%
financeAnalysis.calculateTechnicalIndicator()
financeAnalysis.analysisClosingPrice()
financeAnalysis.plotTechnicalIndicators()
financeAnalysis.closingPriceRelativeStrengthIndex()
financeAnalysis.closingPriceMovingAverageConvergenceDivergence()
financeAnalysis.FinancialCalculation()
merged_data = financeAnalysis.merge_with_news_data("../src/data/processed/news_analysis_results.csv")
merged_data.head()
# Out:
# Sharpe Ratio: 0.83
# Value at Risk (VaR) at 95% confidence level: -5.28%
#         Date     Open     High      Low    Close  Adj Close      Volume  \
# 0 2011-03-03  0.53075  0.53375  0.50600  0.52175   0.478563  1593704000
# 1 2011-03-07  0.52275  0.52450  0.49875  0.51175   0.469391  1019140000
# 2 2011-03-07  0.52275  0.52450  0.49875  0.51175   0.469391  1019140000
# 3 2011-03-08  0.51725  0.52000  0.47800  0.48875   0.448295  1947184000
# 4 2011-03-08  0.51725  0.52000  0.47800  0.48875   0.448295  1947184000
#
#    Dividends  Stock Splits  Daily_Change  ...  stock  sentiment_score  \
# 0        0.0           0.0      0.578306  ...   NVDA            -0.30
# 1        0.0           0.0     -1.396919  ...   NVDA             0.00
# 2        0.0           0.0     -1.396919  ...   NVDA            -0.25
# 3        0.0           0.0     -4.494377  ...   NVDA            -0.50
# 4        0.0           0.0     -4.494377  ...   NVDA             0.50
#
# ...

# %%
merged_data.drop(columns=['domain'], inplace=True)

# %%
merged_data.to_csv('../src/data/processed/merged_data.csv', index=False)

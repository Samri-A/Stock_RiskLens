# %%
# %matplotlib inline

# %%
import sys
sys.path.append("../scripts")
from feature import load_data, plot_correlation_heatmap, plot_publisher_vs_return, comparsion_plot , corelation_plot
from preprocess import preprocess_data

# %%
df = load_data('../src/data/processed/merged_data.csv')
plot_correlation_heatmap(df)
corelation_plot(df, 'Daily_Return', 'sentiment_score')
comparsion_plot(df, 'Daily_Return', 'sentiment_category')
comparsion_plot(df, 'Daily_Return', 'topic')
plot_publisher_vs_return(df)

# %%
df = preprocess_data(df)
df.to_csv('../src/data/processed/cleaned_data.csv', index=False)
